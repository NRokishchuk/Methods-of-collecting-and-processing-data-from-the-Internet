# %%
from bs4 import BeautifulSoup as bs

# Библиотека для работы с HTTP-запросами
import requests

# Модуль Re для регулярных выражений в Python
import re

# Пакет для работы с данными в формате json
import json

# Библиотека для анализа данных, представляющая данные в табличном виде называемом DataFrame
import pandas as pd

# %%
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.135 YaBrowser/21.6.3.757 Yowser/2.5 Safari/537.36'}

# %%
def _parser_hh(vacancy, cnt_page):

    vacancy_date = []
    params = {
        'text': vacancy, \
        'search_field': 'name', \
        'items_on_page': '100', \
        'page': ''
    }
    
    link = 'https://hh.ru/search/vacancy'
       
    html = requests.get(link, params=params, headers=headers)
    
    if html.ok:
        parsed_html = bs(html.text,'html.parser')
        
    for page in range(cnt_page):
        params['page'] = page
        html = requests.get(link, params=params, headers=headers)
        
        if html.ok:
            parsed_html = bs(html.text,'html.parser')
            
            vacancy_items = parsed_html.find('div', {'data-qa': 'vacancy-serp__results'}).find_all('div', {'class': 'vacancy-serp-item'})
                
            for element in vacancy_items:
                vacancy_date.append(hh_get_vacancy_info(element))
                
    return vacancy_date

def hh_get_vacancy_info(element):
    vacancy_date = {}
    # vacancy_name
    vacancy_name = element.find(
        'a', {
            'data-qa': 'vacancy-serp__vacancy-title'}).getText().replace(u'\xa0', u' ')
    vacancy_date['vacancy_name'] = vacancy_name
      
    # company_name
    company_name = element.find('div', {'class': 'vacancy-serp-item__meta-info-company'}).find('a').getText()
    vacancy_date['company_name'] = company_name
    
    # city
    city = element.find(
        'span', {
            'data-qa': 'vacancy-serp__vacancy-address'}).getText().split(', ')[0]
    vacancy_date['city'] = city
    
    # metro station
    metro_station = element.find('span', {'class': 'vacancy-serp-item__meta-info'}).findChild()
    if not metro_station:
        metro_station = None
    else:
        metro_station = metro_station.getText()

    vacancy_date['metro_station'] = metro_station
    
    # salary
    salary = element.find(
        'span', {
            'data-qa': 'vacancy-serp__vacancy-compensation'})
    salary_currency = None
    if not salary:
        salary_min = None
        salary_max = None
        salary_currency = None
    else:
        salary = salary.getText().replace(u'\u202f', u'')
        salary = re.split(r'\s|-', salary)
        if salary[0] == 'до':
            salary_min = None
            salary_max = int(salary[1])
            salary_currency = str(salary[2])
        elif salary[0] == 'от':
            salary_min = int(salary[1])
            salary_max = None
        else:
            salary_min = int(salary[0])
            salary_max = int(salary[2])
            salary_currency = str(salary[3])
    vacancy_date['salary_min'] = salary_min
    vacancy_date['salary_max'] = salary_max
    vacancy_date['salary_currency'] = salary_currency
    
    # vacancy_link
    vacancy_link = element.find(
        'a', {'data-qa': 'vacancy-serp__vacancy-title'}).get('href').split('?')[0]
    vacancy_date['vacancy_link'] = vacancy_link
       
    # site
    vacancy_date['site'] = 'hh.ru'

    return vacancy_date    

def _parser_superjob(vacancy, cnt_page):
    vacancy_date = []
    
    params = {
        'keywords': vacancy, \
        'profession_only': '1', \
        'geo[c][0]': '15', \
        'geo[c][1]': '1', \
        'geo[c][2]': '9', \
        'page': ''
    }
    
    link = 'https://www.superjob.ru/vacancy/search/'
       
    html = requests.get(link, params=params, headers=headers)
    
    for page in range(cnt_page):
        params['page'] = page
        html = requests.get(link, params=params, headers=headers)
        
        if html.ok:
            parsed_html = bs(html.text,'html.parser')
            vacancy_items = parsed_html.find_all('div', {'class': 'f-test-vacancy-item'})
                        
            for item in vacancy_items:
                vacancy_date.append(_parser_item_superjob(item))
                
    return vacancy_date

def _parser_item_superjob(item):
    

    vacancy_date = {}
    
    # vacancy_name
    vacancy_name = item.find('a').getText()
    vacancy_date['vacancy_name'] = vacancy_name
    
    # company_name
    company_name = item.find('span', {'class': 'f-test-text-vacancy-item-company-name'})
    
    if not company_name:
        company_name = item.findParent() \
                            .find('span', {'class': 'f-test-text-vacancy-item-company-name'}) \
                            .getText()
    else:
        company_name = company_name.getText()
    
    vacancy_date['company_name'] = company_name
    
    # city
    company_location = item.find('span', {'class': 'f-test-text-company-item-location'}) \
                            .findChildren()[2] \
                            .getText() \
                            .split(',')
    
    vacancy_date['city'] = company_location[0]
    
    #metro station
    if len(company_location) > 1:
        metro_station = company_location[1]
    else:
        metro_station = None
    
    vacancy_date['metro_station'] = metro_station
    
    #salary
    salary = item.find('span', {'class': 'f-test-text-company-item-salary'}).getText()

    if not salary or salary == 'По договорённости':
        salary_min = None
        salary_max = None
        salary_currency = None

    else:

        salary_split = salary.replace(u'\xa0', u' ').split(' ')
        salary_currency = salary_split[-1]

        if salary_split[0] == 'до':
            salary_min = None
            salary_max = int(salary_split[1] + salary_split[2])
        elif salary_split[0] == 'от':
            salary_min = int(salary_split[1] + salary_split[2])
            salary_max = None
        else:
            salary_min = int(salary_split[0] + salary_split[1])
            salary_max = int(salary_split[-3] + salary_split[-2])

    vacancy_date['salary_min'] = salary_min
    vacancy_date['salary_max'] = salary_max
    vacancy_date['salary_currency'] = salary_currency
    
    
    # link
    vacancy_link = item.find_all('a')
    
    if len(vacancy_link) > 1:
        vacancy_link = vacancy_link[-2]['href']
    else:
        vacancy_link = vacancy_link[0]['href']
    
    vacancy_date['vacancy_link'] = f'https://www.superjob.ru{vacancy_link }'
    
    # site
    vacancy_date['site'] = 'www.superjob.ru'
    
    return vacancy_date

# %%
def parser_vacancy(vacancy, cnt_page):
        
    vacancy_date = []
    vacancy_date.extend(_parser_hh(vacancy, cnt_page)) 
    vacancy_date.extend(_parser_superjob(vacancy, cnt_page))
    
    df = pd.DataFrame(vacancy_date)
    with open('vacancy_date.json', 'w') as f:
        json.dump(vacancy_date, f)
    
    return df
cnt_page = 3
vacancy = 'data science'
df = parser_vacancy(vacancy,cnt_page)

df

# %%
#1. Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии 
#в созданную БД.

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\rokishchuk\anaconda3\lib\site-packages (3.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
from pprint import pprint

# %%
def parser_vacancy_mongo(collection, vacancy):

    vacancy_date = []
    vacancy_date.extend(_parser_hh(vacancy, cnt_page)) 
    vacancy_date.extend(_parser_superjob(vacancy, cnt_page))

    collection.insert_many(vacancy_date)

    return collection

# %%
client = MongoClient('mongodb://localhost:27017')
db = client['vacancy']
collection = db['vacancy']

# %%
cnt_page = 3
vacancy = 'Python'
parser_vacancy_mongo(collection, vacancy)

# %%
#2. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы.

# %%
def find_vacancy(collection, number):

    data = requests.get('https://www.cbr-xml-daily.ru/daily_json.js').json()
    
    result = collection.find(
        {'$or':[
            {'salary_currency': 'руб.',
             '$or': [
                 {'salary_min': {'$gte': number}},  
                 {'salary_max': {'$gte': number}}
             ]},
            {'salary_currency': 'USD',
             '$or': [
                 {'salary_min': {'$gte': data['Valute']['USD']['Value']}},
                 {'salary_max': {'$gte': data['Valute']['USD']['Value']}}
             ]},
            {'salary_currency': 'EUR',
             '$or': [
                 {'salary_min': {'$gte': data['Valute']['EUR']['Value']}},
                 {'salary_max': {'$gte': data['Valute']['EUR']['Value']}}
             ]},
            {'salary_currency': 'грн.',
             '$or': [
                 {'salary_min': {'$gte': data['Valute']['UAH']['Value']}},
                 {'salary_max': {'$gte': data['Valute']['UAH']['Value']}}
             ]},
            {'salary_currency': 'KZT',
             '$or': [
                 {'salary_min': {'$gte': data['Valute']['KZT']['Value']}},
                 {'salary_max': {'$gte': data['Valute']['KZT']['Value']}}
             ]}
        ]},
        {'_id': 0}
    )

    result.sort('salary_min', -1)

    return result

salary = 100000
vacancy_salary = find_vacancy(collection, salary)
for obj in vacancy_salary:
    print(obj)
# Out:
# {'vacancy_name': 'Senior Python Backend Engineer', 'company_name': 'Reef Technologies', 'city': 'Москва', 'metro_station': None, 'salary_min': 506268, 'salary_max': 666792, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47354264', 'site': 'hh.ru'}
# {'vacancy_name': 'Backend-разработчик (Python)', 'company_name': 'ТОО\xa0SOMNIUM', 'city': 'Нур-Султан', 'metro_station': None, 'salary_min': 300000, 'salary_max': 800000, 'salary_currency': 'KZT', 'vacancy_link': 'https://hh.ru/vacancy/47614267', 'site': 'hh.ru'}
# {'vacancy_name': 'Python developer (Senior)', 'company_name': 'ООО\xa0Вайт Код', 'city': 'Санкт-Петербург', 'metro_station': 'Петроградская', 'salary_min': 300000, 'salary_max': 400000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47262469', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle/Senior Python разработчик проектов Data Science', 'company_name': 'ООО\xa0Студия Данных', 'city': 'Пермь', 'metro_station': None, 'salary_min': 200000, 'salary_max': 250000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47223803', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle/Senior Python разработчик проектов Data Science', 'company_name': 'ООО\xa0Студия Данных', 'city': 'Воронеж', 'metro_station': None, 'salary_min': 200000, 'salary_max': 250000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47223801', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle/Senior Python разработчик для проектов Data Science', 'company_name': 'ООО\xa0Студия Данных', 'city': 'Москва', 'metro_station': None, 'salary_min': 200000, 'salary_max': 250000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47223799', 'site': 'hh.ru'}
# {'vacancy_name': 'Python developer удаленно', 'company_name': 'B2Broker Санкт-Петербург', 'city': 'Санкт-Петербург', 'metro_station': 'Горьковская', 'salary_min': 180000, 'salary_max': 230000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/44476355', 'site': 'hh.ru'}
# {'vacancy_name': 'Full stack разработчик на Python (Middle)', 'company_name': 'ООО\xa0Цифровые Платежи', 'city': 'Краснодар', 'metro_station': None, 'salary_min': 170000, 'salary_max': 190000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47755572', 'site': 'hh.ru'}
# {'vacancy_name': 'Разработчик Python (FastAPI / Aiohttp / Flask)', 'company_name': 'Перспектим', 'city': 'Москва', 'metro_station': None, 'salary_min': 160000, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47070215', 'site': 'hh.ru'}
# {'vacancy_name': 'Ведущий программист Python', 'company_name': 'ООО\xa0ФК ПУЛЬС', 'city': 'Москва', 'metro_station': None, 'salary_min': 160000, 'salary_max': 220000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/36618179', 'site': 'hh.ru'}
# {'vacancy_name': 'Python разработчик (Middle)', 'company_name': 'ООО\xa0Строительный Двор', 'city': 'Санкт-Петербург', 'metro_station': None, 'salary_min': 140000, 'salary_max': 220000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47761104', 'site': 'hh.ru'}
# {'vacancy_name': 'Junior Data Engineer (Python)', 'company_name': 'DataFork', 'city': 'Москва', 'metro_station': 'Выставочная', 'salary_min': 120000, 'salary_max': 120000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47018981', 'site': 'hh.ru'}
# {'vacancy_name': 'Python разработчик', 'company_name': 'Coding Team', 'city': 'Санкт-Петербург', 'metro_station': 'Петроградская', 'salary_min': 120000, 'salary_max': 230000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47250451', 'site': 'hh.ru'}
# {'vacancy_name': 'Python developer (middle)', 'company_name': 'ООО\xa0Дорожный консалтинг', 'city': 'Екатеринбург', 'metro_station': None, 'salary_min': 120000, 'salary_max': 150000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47767029', 'site': 'hh.ru'}
# {'vacancy_name': 'Разработчик Python', 'company_name': 'ООО\xa0ЕВАППС', 'city': 'Тула', 'metro_station': None, 'salary_min': 120000, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/44936197', 'site': 'hh.ru'}
# {'vacancy_name': 'Программист Python', 'company_name': 'Тензор', 'city': 'Уфа', 'metro_station': None, 'salary_min': 115000, 'salary_max': 220000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/46417309', 'site': 'hh.ru'}
# {'vacancy_name': 'Backend-разработчик / Python developer (умные дома)', 'company_name': 'ООО\xa0Эктострой', 'city': 'Воронеж', 'metro_station': None, 'salary_min': 100000, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47383047', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle Python Developer', 'company_name': 'FIRECODE', 'city': 'Ростов-на-Дону', 'metro_station': None, 'salary_min': 100000, 'salary_max': 150000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/44818284', 'site': 'hh.ru'}
# {'vacancy_name': 'Разработчик Python', 'company_name': 'The Head', 'city': 'Екатеринбург', 'metro_station': None, 'salary_min': 90000, 'salary_max': 180000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/42905077', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle Python разработчик', 'company_name': 'ООО\xa0СЕРВИСХАБ', 'city': 'Владимир', 'metro_station': None, 'salary_min': 90000, 'salary_max': 130000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/46091871', 'site': 'hh.ru'}
# {'vacancy_name': 'Python разработчик', 'company_name': 'ООО\xa0Рилайнс', 'city': 'Москва', 'metro_station': None, 'salary_min': 80000, 'salary_max': 150000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47620506', 'site': 'hh.ru'}
# {'vacancy_name': 'Разработчик Python', 'company_name': 'ДАТА+', 'city': 'Москва', 'metro_station': None, 'salary_min': 80000, 'salary_max': 120000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47750193', 'site': 'hh.ru'}
# {'vacancy_name': 'Python разработчик', 'company_name': 'ЗАО\xa0НОРСИ-ТРАНС', 'city': 'Москва', 'metro_station': None, 'salary_min': 80000, 'salary_max': 120000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47535099', 'site': 'hh.ru'}
# {'vacancy_name': 'Программист Python', 'company_name': 'ООО\xa0Артистраж', 'city': 'Москва', 'metro_station': 'Выставочная', 'salary_min': 60000, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47450602', 'site': 'hh.ru'}
# {'vacancy_name': 'Python-разработчик (Django, DRF)', 'company_name': 'ООО\xa0Фабрика Решений', 'city': 'Москва', 'metro_station': 'Сухаревская', 'salary_min': 60000, 'salary_max': 150000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/39736489', 'site': 'hh.ru'}
# {'vacancy_name': 'Machine Learning Engineer (Python)', 'company_name': 'Starnavi', 'city': 'Санкт-Петербург', 'metro_station': None, 'salary_min': 3000, 'salary_max': 5000, 'salary_currency': 'USD', 'vacancy_link': 'https://hh.ru/vacancy/47025915', 'site': 'hh.ru'}
# {'vacancy_name': 'Discord Bot Developer (Python)', 'company_name': 'Abelohost BV', 'city': 'Нидерланды', 'metro_station': None, 'salary_min': 1000, 'salary_max': 1500, 'salary_currency': 'EUR', 'vacancy_link': 'https://hh.ru/vacancy/47708896', 'site': 'hh.ru'}
# {'vacancy_name': 'Python / Django developer', 'company_name': 'UAB Loberta', 'city': 'Москва', 'metro_station': None, 'salary_min': 1000, 'salary_max': 2500, 'salary_currency': 'USD', 'vacancy_link': 'https://hh.ru/vacancy/47731874', 'site': 'hh.ru'}
# {'vacancy_name': 'Team Lead Python Engineer', 'company_name': 'КА Натальи Зотовой', 'city': 'Минск', 'metro_station': None, 'salary_min': None, 'salary_max': 8000, 'salary_currency': 'USD', 'vacancy_link': 'https://hh.ru/vacancy/47572828', 'site': 'hh.ru'}
# {'vacancy_name': 'Python разработчик', 'company_name': 'Точка', 'city': 'Москва', 'metro_station': None, 'salary_min': None, 'salary_max': 290000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47682360', 'site': 'hh.ru'}
# {'vacancy_name': 'Back-end python программист', 'company_name': 'ООО\xa0ВойсЛинк', 'city': 'Москва', 'metro_station': 'Тимирязевская', 'salary_min': None, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/45987039', 'site': 'hh.ru'}
# {'vacancy_name': 'Middle python-разработчик (aiohttp)', 'company_name': 'KTS', 'city': 'Москва', 'metro_station': 'Бауманская', 'salary_min': None, 'salary_max': 200000, 'salary_currency': 'руб.', 'vacancy_link': 'https://hh.ru/vacancy/47490844', 'site': 'hh.ru'}

# %%
def insert_vacancies(collection):
    vacancy_date = []
    vacancy_date.extend(_parser_hh(vacancy, cnt_page)) 
    vacancy_date.extend(_parser_superjob(vacancy, cnt_page))
    
    i = 0
    for v in vacancy_date:
        try:
            collection.insert_one(v)
            i = i+1
        except:
            pass
   
    return i      
client = MongoClient('mongodb://localhost:27017')
db = client['vacancy']
collection = db['vacancy']
collection.create_index("vacancy_link", unique=True)
cnt_page = 5
vacancy = 'Python'
vacancy_date = []
cnt = insert_vacancies(collection )
print(f'Добавлено вакансий: {cnt}')
print(f'Вакансий всего: {collection.count_documents({})}')
# Out:
# Добавлено вакансий: 0
# Вакансий всего: 207
